# %%
dbutils.fs.help()

# %%
dbutils.fs.ls('dbfs:/')

# %%
dbutils.fs.ls('dbfs:/databricks-datasets/')

# %%
display(dbutils.fs.head('dbfs:/databricks-datasets/COVID/covid-19-data/us-states.csv'))

# %%
dbutils.fs.mkdirs('dbfs:/Test/')

# %%
dbutils.widgets.help()

# %%
dbutils.widgets.combobox(name='combobox_name',defaultValue='employee',choices=['tester','manager','admin','developer'],label='Department_label')

# %%
dbutils.widgets.dropdown(name='dropdown_name',defaultValue='employee',choices=['tester','manager','admin','developer'],label='Department_label')

# %%
dbutils.widgets.get('combobox_name')

# %%
dbutils.widgets.text(name='text_name',defaultValue='',label='Year')

# %%
result=dbutils.widgets.get('text_name')
print(f'The value of the widget is {result}')

# %%
dbutils.widgets.remove('combobox_name')
